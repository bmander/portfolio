# %%
import sys
import os
import imageio

# %%
for fn in sorted( os.listdir(".") ):
    try:
        fp = imageio.imread(fn)
        w,h,_ = fp.shape
        print "{ src: 'img/%s', width: %d, height: %d },"%(fn,h,w)
    except ValueError, e:
        continue
# Out:
# { src: 'img/Screen Shot 2018-05-01 at 1.54.49 PM.png', width: 1580, height: 1030 },
# { src: 'img/artsy_01.jpg', width: 1128, height: 880 },
# { src: 'img/artsy_02.png', width: 1680, height: 1050 },
# { src: 'img/artsy_03.png', width: 1000, height: 1055 },
# { src: 'img/artsy_04.png', width: 4000, height: 2300 },
# { src: 'img/artsy_05.png', width: 6000, height: 1412 },
# { src: 'img/artsy_06.png', width: 1288, height: 1056 },
# { src: 'img/artsy_08.png', width: 7015, height: 4960 },
# { src: 'img/bikescore_modeshare.jpg', width: 1224, height: 954 },
# { src: 'img/bikescore_slope_bw.jpg', width: 2048, height: 1822 },
# { src: 'img/bikescore_slope_bw_rainier.jpg', width: 1292, height: 1136 },
# { src: 'img/bikescore_slope_color_ny.jpg', width: 672, height: 1256 },
# { src: 'img/bikescore_slope_color_seattle.jpg', width: 1616, height: 1400 },
# { src: 'img/bikescore_slope_color_sf.jpg', width: 1318, height: 1140 },
# { src: 'img/bikescore_total.jpg', width: 1684, height: 1318 },
# ...
